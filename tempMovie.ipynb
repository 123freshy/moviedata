# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('df1.csv')
df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline   ...    history horror  music mistery romance  \
# 0           The park is open.   ...      False  False  False   False   False
# ...

# %%
#just checking the last columns populated correctly
df.iloc[1:7, 21:41]
# Out:
#   action adventure animation comedy  crime documentary  drama family fantasy  \
# 1   True      True     False  False  False       False  False  False   False
# 2  False      True     False  False  False       False  False  False   False
# 3   True      True     False  False  False       False  False  False    True
# 4   True     False     False  False   True       False  False  False   False
# 5  False      True     False  False  False       False   True  False   False
# 6   True      True     False  False  False       False  False  False   False
#
#   foreign history horror  music mistery romance science_fiction tv_movie  \
# 1   False   False  False  False   False   False            True    False
# 2   False   False  False  False   False   False            True    False
# 3   False   False  False  False   False   False            True    False
# 4   False   False  False  False   False   False           False    False
# ...

# %%
#This gives us the total for each genre.  Since it's a boolean column the sum is a count of all "True" values = 1
gen1 = np.sum(df['action'])
gen2 = np.sum(df['adventure'])
gen3 = np.sum(df['animation'])
gen4 = np.sum(df['comedy'])
gen5 = np.sum(df['crime'])
gen6 = np.sum(df['documentary'])
gen7 = np.sum(df['drama'])
gen8 = np.sum(df['family'])
gen9 = np.sum(df['fantasy'])
gen10 = np.sum(df['foreign'])
gen11 = np.sum(df['history'])
gen12 = np.sum(df['horror'])
gen13 = np.sum(df['music'])
gen14 = np.sum(df['mistery'])
gen15 = np.sum(df['romance'])
gen16 = np.sum(df['science_fiction'])
gen17 = np.sum(df['tv_movie'])
gen18 = np.sum(df['thriller'])
gen19 = np.sum(df['war'])
gen20 = np.sum(df['western'])

# %%
gen1
# Out:
# 2385

# %%
gentotals
# Out:
# [2385, 1471, 699, 3793]

# %%
genrev1 = df.query('action == True')['revenue_adj'].mean()
genrev1
# Out:
# 91720204.01996124

# %%
headers = list(df.columns.values)
genheads = headers [21:41]
print (genheads)
# Out:
# ['action', 'adventure', 'animation', 'comedy', 'crime', 'documentary', 'drama', 'family', 'fantasy', 'foreign', 'history', 'horror', 'music', 'mistery', 'romance', 'science_fiction', 'tv_movie', 'thriller', 'war', 'western']

# %% [markdown]
# ## Was able to clean up repetetive code with this function for gentotals. putting all gentotals in one list

# %%
genres = genheads
gentotals = []
for gen in genres:
    gentotals.append(np.sum(df[gen]))
print(gentotals)
# Out:
# [2385, 1471, 699, 3793, 1355, 520, 4761, 1231, 916, 188, 334, 1637, 408, 0, 1712, 1230, 167, 2908, 270, 165]

# %%
#calculate the average adjusted revenue per genre
genrev1 = df.query('action == True')['revenue_adj'].mean()
genrev2 = df.query('adventure == True')['revenue_adj'].mean()
genrev3 = df.query('animation == True')['revenue_adj'].mean()
genrev4 = df.query('comedy == True')['revenue_adj'].mean()
genrev5 = df.query('crime == True')['revenue_adj'].mean()
genrev6 = df.query('documentary == True')['revenue_adj'].mean()
genrev7 = df.query('drama == True')['revenue_adj'].mean()
genrev8 = df.query('family == True')['revenue_adj'].mean()
genrev9 = df.query('fantasy == True')['revenue_adj'].mean()
genrev10 = df.query('foreign == True')['revenue_adj'].mean()
genrev11 = df.query('history == True')['revenue_adj'].mean()
genrev12 = df.query('horror == True')['revenue_adj'].mean()
genrev13 = df.query('music == True')['revenue_adj'].mean()
genrev14 = df.query('mistery == True')['revenue_adj'].mean()
genrev15 = df.query('romance == True')['revenue_adj'].mean()
genrev16 = df.query('science_fiction == True')['revenue_adj'].mean()
genrev17 = df.query('tv_movie == True')['revenue_adj'].mean()
genrev18 = df.query('thriller == True')['revenue_adj'].mean()
genrev19 = df.query('war == True')['revenue_adj'].mean()
genrev20 = df.query('western == True')['revenue_adj'].mean()

# %%
genres2 = genheads
genrev = []
for gen in genres2:
    genrev.append(df.query('df[gen] == True')['revenue_adj'].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# ~\AppData\Local\Continuum\anaconda3\lib\collections\__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# ~\AppData\Local\Continuum\anaconda3\lib\collections\__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'df'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
